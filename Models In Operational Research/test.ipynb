# %%
pip install gurobipy
# Out:
# ...
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.2 MB 653.6 kB/s eta 0:00:16
#     --------------------------------------- 0.2/10.2 MB 1.6 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/10.2 MB 3.0 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/10.2 MB 4.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.3/10.2 MB 5.2 MB/s eta 0:00:02
#    ------ --------------------------------- 1.7/10.2 MB 5.9 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.3 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/10.2 MB 6.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.7/10.2 MB 6.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/10.2 MB 6.5 MB/s eta 0:00:02
# ...
