# %%
import gurobipy as gp
from gurobipy import GRB, quicksum
import numpy as np
import pandas as pd

# %%
distributions_df = pd.read_csv(r"C:\Users\johns\OneDrive\Desktop\MBAN Semester 3\OMIS 6000 - Models & Applications in Operational Research\Assignment 3 Files\Questions\distributions.csv")
cost_matrix_df = pd.read_csv(r"C:\Users\johns\OneDrive\Desktop\MBAN Semester 3\OMIS 6000 - Models & Applications in Operational Research\Assignment 3 Files\Questions\cost_matrix.csv")

# %%
selling_price = 49.99
ordering_cost = 24.44
n_stores = len(distributions_df)
n_scenarios = 100
n_trials = 50
opportunity_cost_per_unit = selling_price - ordering_cost

# %%
def generate_demand_scenarios(n_trials, n_scenarios, distributions_df):
    demand_scenarios = np.zeros((n_trials, n_scenarios, n_stores))
    for trial in range(n_trials):
        for scenario in range(n_scenarios):
            for store in range(n_stores):
                n = distributions_df.loc[store, 'n']
                p = distributions_df.loc[store, 'p']
                demand_scenarios[trial, scenario, store] = np.random.binomial(n, p)
    return demand_scenarios

# %%
def solve_optimization_model_no_transshipment(demand_scenario):
    model = gp.Model("OptimalOrderQuantityNoTransshipment")
    model.setParam('OutputFlag', 0)

    # Decision variables
    y = model.addVars(n_stores, vtype=GRB.CONTINUOUS, name="order_qty", lb=0)
    unmet_demand = model.addVars(n_stores, vtype=GRB.CONTINUOUS, name="unmet_demand", lb=0)

    # Objective function
    model.setObjective(
        quicksum(ordering_cost * y[i] for i in range(n_stores)) + 
        quicksum(unmet_demand[i] * opportunity_cost_per_unit for i in range(n_stores)), 
        GRB.MINIMIZE
    )

    # Constraints
    for i in range(n_stores):
        model.addConstr(y[i] + unmet_demand[i] >= demand_scenario[i], name=f"demand_met_{i}")

    model.optimize()

    if model.status == GRB.OPTIMAL:
        return [y[i].X for i in range(n_stores)], model.ObjVal
    else:
        return None, None

# %%
def solve_optimization_model_with_transshipment(demand_scenario):
    model = gp.Model("OptimalOrderQuantityWithTransshipment")
    model.setParam('OutputFlag', 1)  # Enable output for debugging

    # Decision variables
    y = model.addVars(n_stores, vtype=GRB.CONTINUOUS, name="order_qty")
    x = model.addVars(n_stores, n_stores, vtype=GRB.CONTINUOUS, name="transshipment")
    unmet_demand = model.addVars(n_stores, vtype=GRB.CONTINUOUS, name="unmet_demand", lb=0)
    z = model.addVars(n_stores, n_stores, vtype=GRB.BINARY, name="transshipment_indicator")

    # Objective function
    model.setObjective(
        quicksum(ordering_cost * y[i] for i in range(n_stores)) + 
        quicksum(cost_matrix_df.iloc[i, j] * x[i, j] for i in range(n_stores) for j in range(n_stores) if i != j) + 
        quicksum(opportunity_cost_per_unit * unmet_demand[i] for i in range(n_stores)),
        GRB.MINIMIZE
    )

    # Constraints
    M = max(cost_matrix_df.max().max(), np.max(demand_scenario)) * 1.1  # Set M to be slightly larger than the maximum possible transshipment quantity
    
    for i in range(n_stores):
        model.addConstr(
            y[i] + quicksum(x[j,i] for j in range(n_stores) if j != i) -
            quicksum(x[i,j] for j in range(n_stores) if i != j) + unmet_demand[i] == demand_scenario[i],
            "DemandFulfillment_{}".format(i)
        )

    for i in range(n_stores):
        for j in range(n_stores):
            if i != j:
                model.addConstr(
                    x[i, j] <= M * z[i, j],
                    "TransshipmentDecision_{}_{}".format(i, j)
                )

    model.optimize()

    if model.status == GRB.OPTIMAL:
        return [y[i].X for i in range(n_stores)], model.ObjVal
    else:
        return None, None

# %%
demand_scenarios = generate_demand_scenarios(n_trials, n_scenarios, distributions_df)

# %%
# No transshipment scenario
average_order_quantities_no_transshipment = np.zeros(n_stores)
average_total_cost_no_transshipment = 0

# %%
for trial in range(n_trials):
    for scenario in range(n_scenarios):
        demand_scenario = demand_scenarios[trial, scenario, :]
        optimal_order_quantities, total_cost = solve_optimization_model_no_transshipment(demand_scenario)
        if optimal_order_quantities is not None:
            average_order_quantities_no_transshipment += np.array(optimal_order_quantities)
            average_total_cost_no_transshipment += total_cost
# Out:
# Restricted license - for non-production use only - expires 2025-11-24

# %%
average_order_quantities_no_transshipment /= (n_trials * n_scenarios)
average_total_cost_no_transshipment /= (n_trials * n_scenarios)

print(f"Average Order Quantities (No Transshipment): {average_order_quantities_no_transshipment}")
print(f"Average Total Cost (No Transshipment): {average_total_cost_no_transshipment}")
# Out:
# Average Order Quantities (No Transshipment): [ 89.9416  51.8344  99.054   66.7476  53.4118  61.6404 114.6898 110.0004
#   99.6158  98.2774  82.3936  95.2226 120.1444 121.8576 115.3974]
# Average Total Cost (No Transshipment): 33732.791872

# %%
# With transshipment scenario
average_order_quantities_with_transshipment = np.zeros(n_stores)
average_total_cost_with_transshipment = 0

# %%
for trial in range(n_trials):
    for scenario in range(n_scenarios):
        demand_scenario = demand_scenarios[trial, scenario, :]
        optimal_order_quantities, total_cost = solve_optimization_model_with_transshipment(demand_scenario)
        if optimal_order_quantities is not None:
            average_order_quantities_with_transshipment += np.array(optimal_order_quantities)
            average_total_cost_with_transshipment += total_cost
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xceaf1afa
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 34191.560000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      34191.5600 34191.5600  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 34191.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.419156000000e+04, best bound 3.419156000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xc9b310ec
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 34093.800000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      34093.8000 34093.8000  0.00%     -    0s
#
# Explored 1 nodes (34 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 34093.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.409380000000e+04, best bound 3.409380000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xd7a151ce
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 34264.880000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 32 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      34264.8800 34264.8800  0.00%     -    0s
#
# Explored 1 nodes (32 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 34264.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.426488000000e+04, best bound 3.426488000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xcd0f95c0
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33751.640000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 32 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33751.6400 33751.6400  0.00%     -    0s
#
# Explored 1 nodes (32 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33751.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.375164000000e+04, best bound 3.375164000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x296e2323
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33311.720000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33311.7200 33311.7200  0.00%     -    0s
#
# Explored 1 nodes (34 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33311.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.331172000000e+04, best bound 3.331172000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x2d94db1a
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [6e+01, 1e+02]
# Found heuristic solution: objective 34167.120000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      34167.1200 34167.1200  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 34167.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.416712000000e+04, best bound 3.416712000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x359f63c5
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33605.000000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33605.0000 33605.0000  0.00%     -    0s
#
# Explored 1 nodes (34 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33605
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.360500000000e+04, best bound 3.360500000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xe3c7ba0c
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33996.040000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33996.0400 33996.0400  0.00%     -    0s
#
# Explored 1 nodes (34 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33996
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.399604000000e+04, best bound 3.399604000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x0172a730
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 34240.440000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 30 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      34240.4400 34240.4400  0.00%     -    0s
#
# Explored 1 nodes (30 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 34240.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.424044000000e+04, best bound 3.424044000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xbe39ab5c
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33458.360000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 36 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33458.3600 33458.3600  0.00%     -    0s
#
# Explored 1 nodes (36 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33458.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.345836000000e+04, best bound 3.345836000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x5f4f38ae
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33776.080000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33776.0800 33776.0800  0.00%     -    0s
#
# Explored 1 nodes (34 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33776.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.377608000000e+04, best bound 3.377608000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xdc6a6194
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33996.040000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33996.0400 33996.0400  0.00%     -    0s
#
# Explored 1 nodes (34 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33996
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.399604000000e+04, best bound 3.399604000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x121dab0a
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33605.000000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 36 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33605.0000 33605.0000  0.00%     -    0s
#
# Explored 1 nodes (36 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33605
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.360500000000e+04, best bound 3.360500000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xffe3f606
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33727.200000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33727.2000 33727.2000  0.00%     -    0s
#
# Explored 1 nodes (34 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33727.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.372720000000e+04, best bound 3.372720000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x01c29d81
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33189.520000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33189.5200 33189.5200  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33189.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.318952000000e+04, best bound 3.318952000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x7484b8c8
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33727.200000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 31 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33727.2000 33727.2000  0.00%     -    0s
#
# Explored 1 nodes (31 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33727.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.372720000000e+04, best bound 3.372720000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x2e0c8133
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33385.040000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 36 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33385.0400 33385.0400  0.00%     -    0s
#
# Explored 1 nodes (36 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33385
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.338504000000e+04, best bound 3.338504000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xdd57a095
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33605.000000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33605.0000 33605.0000  0.00%     -    0s
#
# Explored 1 nodes (34 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33605
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.360500000000e+04, best bound 3.360500000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xf657ca96
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33898.280000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33898.2800 33898.2800  0.00%     -    0s
#
# Explored 1 nodes (34 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33898.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.389828000000e+04, best bound 3.389828000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x29cf2f66
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33996.040000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 36 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33996.0400 33996.0400  0.00%     -    0s
#
# Explored 1 nodes (36 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33996
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.399604000000e+04, best bound 3.399604000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x77bb03bf
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 32871.800000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      32871.8000 32871.8000  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 32871.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.287180000000e+04, best bound 3.287180000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x12ed16ae
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33702.760000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33702.7600 33702.7600  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33702.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.370276000000e+04, best bound 3.370276000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x6a5245f8
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33287.280000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33287.2800 33287.2800  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33287.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.328728000000e+04, best bound 3.328728000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x48944aa8
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33849.400000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33849.4000 33849.4000  0.00%     -    0s
#
# Explored 1 nodes (34 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33849.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.384940000000e+04, best bound 3.384940000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x713d4141
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 34020.480000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      34020.4800 34020.4800  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 34020.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.402048000000e+04, best bound 3.402048000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x7e5ba283
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 32896.240000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 31 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      32896.2400 32896.2400  0.00%     -    0s
#
# Explored 1 nodes (31 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 32896.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.289624000000e+04, best bound 3.289624000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x2dd2afaf
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33409.480000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 32 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33409.4800 33409.4800  0.00%     -    0s
#
# Explored 1 nodes (32 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33409.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.340948000000e+04, best bound 3.340948000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x9f90b6ca
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+01, 1e+02]
# Found heuristic solution: objective 33385.040000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 36 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33385.0400 33385.0400  0.00%     -    0s
#
# Explored 1 nodes (36 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33385
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.338504000000e+04, best bound 3.338504000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xdaaddcf3
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 34460.400000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      34460.4000 34460.4000  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 34460.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.446040000000e+04, best bound 3.446040000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xc6494abe
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33336.160000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 31 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33336.1600 33336.1600  0.00%     -    0s
#
# Explored 1 nodes (31 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33336.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.333616000000e+04, best bound 3.333616000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x54d1cca3
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33971.600000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 32 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33971.6000 33971.6000  0.00%     -    0s
#
# Explored 1 nodes (32 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33971.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.397160000000e+04, best bound 3.397160000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xef854f35
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [6e+01, 1e+02]
# Found heuristic solution: objective 33922.720000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33922.7200 33922.7200  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33922.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.392272000000e+04, best bound 3.392272000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xe1fa2259
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33311.720000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 31 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33311.7200 33311.7200  0.00%     -    0s
#
# Explored 1 nodes (31 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33311.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.331172000000e+04, best bound 3.331172000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x897dc767
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33947.160000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33947.1600 33947.1600  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33947.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.394716000000e+04, best bound 3.394716000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x7510b0f8
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33678.320000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33678.3200 33678.3200  0.00%     -    0s
#
# Explored 1 nodes (34 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33678.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.367832000000e+04, best bound 3.367832000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x3e5da0ed
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33189.520000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33189.5200 33189.5200  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds (0.00 work units)
# ...
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x9caab33b
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 34460.400000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 31 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      34460.4000 34460.4000  0.00%     -    0s
#
# Explored 1 nodes (31 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 34460.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.446040000000e+04, best bound 3.446040000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xfd27fc19
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 34460.400000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 29 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      34460.4000 34460.4000  0.00%     -    0s
#
# Explored 1 nodes (29 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 34460.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.446040000000e+04, best bound 3.446040000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x10322c13
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33385.040000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 31 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33385.0400 33385.0400  0.00%     -    0s
#
# Explored 1 nodes (31 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33385
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.338504000000e+04, best bound 3.338504000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xbc1853af
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33458.360000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 36 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33458.3600 33458.3600  0.00%     -    0s
#
# Explored 1 nodes (36 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33458.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.345836000000e+04, best bound 3.345836000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xe5b7845e
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [6e+01, 1e+02]
# Found heuristic solution: objective 33751.640000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33751.6400 33751.6400  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33751.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.375164000000e+04, best bound 3.375164000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x05de2884
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [6e+01, 1e+02]
# Found heuristic solution: objective 34069.360000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 32 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      34069.3600 34069.3600  0.00%     -    0s
#
# Explored 1 nodes (32 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 34069.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.406936000000e+04, best bound 3.406936000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x5ad55335
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33507.240000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33507.2400 33507.2400  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33507.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.350724000000e+04, best bound 3.350724000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xcb93a5c4
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33702.760000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33702.7600 33702.7600  0.00%     -    0s
#
# Explored 1 nodes (34 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33702.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.370276000000e+04, best bound 3.370276000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xbba896fd
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33776.080000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 35 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33776.0800 33776.0800  0.00%     -    0s
#
# Explored 1 nodes (35 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33776.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.377608000000e+04, best bound 3.377608000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x4977c785
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33653.880000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33653.8800 33653.8800  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33653.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.365388000000e+04, best bound 3.365388000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0x47393c4c
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33629.440000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33629.4400 33629.4400  0.00%     -    0s
#
# Explored 1 nodes (34 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33629.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.362944000000e+04, best bound 3.362944000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13700H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 225 rows, 480 columns and 870 nonzeros
# Model fingerprint: 0xb0e91a8a
# Variable types: 255 continuous, 225 integer (225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
# Found heuristic solution: objective 33702.760000
# Presolve removed 210 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 225 columns, 435 nonzeros
# Variable types: 225 continuous, 0 integer (0 binary)
#
# Root relaxation: cutoff, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      33702.7600 33702.7600  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 1: 33702.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.370276000000e+04, best bound 3.370276000000e+04, gap 0.0000%

# %%
average_order_quantities_with_transshipment /= (n_trials * n_scenarios)
average_total_cost_with_transshipment /= (n_trials * n_scenarios)

print(f"Average Order Quantities (With Transshipment): {average_order_quantities_with_transshipment}")
print(f"Average Total Cost (With Transshipment): {average_total_cost_with_transshipment}")
# Out:
# Average Order Quantities (With Transshipment): [ 89.9744  51.821   99.1168  66.769   53.4412  61.7918 114.6776 110.035
#   99.6034  98.2978  82.3864  95.2104 120.1126 121.776  115.3376]
# Average Total Cost (With Transshipment): 33735.77844000001

# %%
n_scenarios = 500
n_trials = 1

# %%
demand_scenarios = generate_demand_scenarios(n_trials, n_scenarios, distributions_df)[0]
average_demand = np.mean(demand_scenarios, axis=0)
_, deterministic_total_cost = solve_optimization_model_with_transshipment(average_demand)

# %%
total_cost_stochastic = 0

# %%
for scenario in demand_scenarios:
    optimal_order_quantities, scenario_cost = solve_optimization_model_with_transshipment(scenario)
    if optimal_order_quantities is not None:
        total_cost_stochastic += scenario_cost

# %%
average_total_cost_stochastic = total_cost_stochastic / n_scenarios
VSS = average_total_cost_stochastic - deterministic_total_cost

# %%
print(f"EEV (Expected Ex-post Value): {average_total_cost_stochastic}")
print(f"VSS (Value of the Stochastic Solution): {VSS}")
# Out:
# EEV (Expected Ex-post Value): 33728.666400000024
# VSS (Value of the Stochastic Solution): 1.4551915228366852e-11
